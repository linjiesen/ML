# %% [markdown]
# # Overfitting and Underfitting

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.seed(666)
x = np.random.uniform(-3.0, 3.0, size=100)
X = x.reshape(-1, 1)
y = 0.5 * x ** 2 + x + 2 + np.random.normal(0, 1, size=100)

# %%
plt.scatter(x, y)

# %% [markdown]
# # Method of LinearRegression

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression()
lin_reg.fit(X, y)
lin_reg.score(X, y)
# Out:
# 0.4953707811865009

# %%
y_predict = lin_reg.predict(X)
plt.scatter(x, y)
plt.plot(np.sort(x), y_predict[np.argsort(x)], color='r')

# %%
from sklearn.metrics import mean_squared_error

y_predict = lin_reg.predict(X)
mean_squared_error(y, y_predict)
# Out:
# 3.0750025765636577

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler

def PolynomialRegression(degree):
    return Pipeline([
        ("poly", PolynomialFeatures(degree=degree)),
        ("std_scaler", StandardScaler()),
        ("lin_reg", LinearRegression())
    ])

# %%
poly2_reg = PolynomialRegression(degree=2)
poly2_reg.fit(X, y)
# Out:
# Pipeline(memory=None,
#      steps=[('poly', PolynomialFeatures(degree=2, include_bias=True, interaction_only=False)), ('std_scaler', StandardScaler(copy=True, with_mean=True, with_std=True)), ('lin_reg', LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False))])

# %%
y2_predict = poly2_reg.predict(X)
mean_squared_error(y, y2_predict)
# Out:
# 1.0987392142417858

# %%
plt.scatter(x, y)
plt.plot(np.sort(x), y2_predict[np.argsort(x)], color='r')

# %%
poly10_reg = PolynomialRegression(degree=10)
poly10_reg.fit(X, y)

y10_predict = poly10_reg.predict(X)
mean_squared_error(y, y10_predict)
# Out:
# 1.050846676376417

# %%
y10_predict
# Out:
# array([4.23795992, 6.24913785, 4.02428234, 4.45378103, 8.37354679,
#        3.50243108, 1.51218861, 2.86095379, 2.61111129, 1.76445015,
#        1.71883868, 4.58810561, 1.75502966, 4.24129778, 1.70294277,
#        4.90424981, 3.88879163, 2.49613607, 2.51433621, 1.64556006,
#        3.16525642, 4.44955347, 1.70077258, 1.73145266, 7.86997273,
#        8.55287936, 2.03103232, 1.65661804, 2.76858255, 1.7147822 ,
#        7.42052553, 3.41856606, 5.65163225, 2.22167364, 1.50531393,
#        4.57847249, 1.63683835, 2.76229713, 4.91325425, 1.65906391,
#        2.74336065, 1.60368148, 2.06811203, 5.86522781, 1.76347773,
#        1.67183504, 2.41845337, 7.73159759, 6.44625193, 1.50248128,
#        1.56637889, 3.36795024, 1.7089984 , 1.67615795, 7.53148344,
#        5.06268158, 4.86620211, 1.49861079, 4.92386522, 1.50612607,
#        1.82417152, 7.29876849, 4.3830785 , 3.97786465, 1.65363262,
#        1.48248293, 3.35989012, 1.64268745, 1.79340953, 1.70155047,
#        1.7109785 , 1.68219811, 2.57919609, 1.47758778, 8.46937805,
#        4.53958482, 4.38896146, 7.52061167, 8.43103959, 1.73363593,
#        4.35044812, 1.98768363, 6.83173712, 3.38152017, 8.41467707,
#        1.92868933, 2.95069401, 4.44601924, 3.96383213, 2.85398975,
#        8.82254761, 1.67578504, 8.34934969, 1.48169513, 9.07118561,
#        3.70124455, 4.25267232, 1.48384978, 1.9346318 , 2.44387337])

# %%
plt.scatter(x, y)
plt.plot(np.sort(x), y10_predict[np.argsort(x)], color='r')

# %%
poly100_reg = PolynomialRegression(degree=100)
poly100_reg.fit(X, y)

y100_predict = poly100_reg.predict(X)
mean_squared_error(y, y100_predict)
# Out:
# 0.6787631176364373

# %%
plt.scatter(x, y)
plt.plot(np.sort(x), y100_predict[np.argsort(x)], color='r')

# %%
X_plot = np.linspace(-3, 3, 100).reshape(100, 1)
y_plot = poly100_reg.predict(X_plot)

plt.scatter(x, y)
plt.plot(X_plot[:,0], y_plot, color='r')
plt.axis([-3, 3, -1, 10])
# Out:
# [-3, 3, -1, 10]
